# %%
import os
os.chdir('..')
# %pip install -e .
# Out:
# Obtaining file:///C:/Users/adolf/Desktop/cvrp
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# ...
#   Building editable for cvrp (pyproject.toml): started
#   Building editable for cvrp (pyproject.toml): finished with status 'done'
#   Created wheel for cvrp: filename=cvrp-0.1.0-0.editable-py3-none-any.whl size=2031 sha256=7344a84f2e5240ca08b17d8418974bd1f85db23d48a042fc9b469eaf063a95d1
# ...

# %%
import sys
from pathlib import Path

# Make src importable
sys.path.insert(0, str(Path.cwd().parent / "src"))
# Out:
# c:\Users\adolf\Desktop\cvrp

# %%
from readers.instance_reader import InstanceReader 

# Create reader (defaults to the repo 'instances' folder)
ir = InstanceReader("instances")

# Read an example from family 'A' (choose any existing A-... name without extension)
inst = ir.read('A', 'A-n32-k5')

# Brief summary
print(f"Capacity: {inst.capacity}; depot=({inst.depot.x},{inst.depot.y}); n_nodes={len(inst.nodes)}")
print('First 5 nodes (x, y, demand):')
for n in inst.nodes[:5]:
    print(n.x, n.y, n.demand)
print('dist_matrix shape:', getattr(inst, 'dist_matrix').shape)
# Out:
# Capacity: 100; depot=(82,76); n_nodes=31
# First 5 nodes (x, y, demand):
# 96 44 19
# 50 5 21
# 49 8 6
# 13 7 19
# 29 89 7
# dist_matrix shape: (32, 32)
